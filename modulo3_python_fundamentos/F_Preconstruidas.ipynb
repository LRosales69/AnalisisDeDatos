# %% [markdown]
# FUNCIONES PRECONSTRUIDAS

# %% [markdown]
# Funciones Nativas (built-in functions)
#
# Son funciones que están integradas en Python, y que el usuario puede utilizar sin necesidad de importar módulos externos.
# ![Figura-115-Imagen-de-funciones-predefinidas-en-Python.png](data:image/png;base64,...)
#
# Fuente: https://www.researchgate.net/figure/Figura-115-Imagen-de-funciones-predefinidas-en-Python_fig14_335128780

# %%
Ejemplos:

# %%
print("Hola Mundo")# Muestra texto o datos en pantalla
# Out:
# Hola Mundo

# %%
nombre=input("Ingrese su nombre:") # captura datos del usuario por teclado
# Out:
# Ingrese su nombre:Lucileima

# %%
len("Hola") # Devuelve la longitud de una cadena, lista, tupla
# Out:
# 4

# %%
x=3
type(x) # Devuelve el tipo de dato de una variable
# Out:
# int

# %%
int(3.14) # Convierte un número a entero
# Out:
# 3

# %%
float(3) # Convierte un número a flotante
# Out:
# 3.0

# %%
str(3) # Convierte un número a cadena
# Out:
# '3'

# %%
sum([9,6,10]) # Suma los elementos de una lista o tupla
# Out:
# 25

# %%
max(4,7,2) # Devuelve el valor máximo de una lista o tupla
# Out:
# 7

# %%
min(4,7,2) # Devuelve el valor mínimo de una lista o tupla
# Out:
# 2

# %%
abs(-10) # Devuelve el valor absoluto de un número
# Out:
# 10

# %%
round(3.14159,2) # Redondea un número a un número de decimales especificado
# Out:
# 3.14

# %%
pow(2,3)
# Out:
# 8

# %%
z=complex(3,4)
print(z)
print(z.real)
print(z.imag)
# Out:
# (3+4j)
# 3.0
# 4.0

# %%
print(chr(65)) # Convierte un número entero que representa un código Unicode en su carácter correspondiente.
print(chr(8364))
print(ord('A'))
# Out:
# A
# €
# 65

# %%
a="carro"
a.upper()
# Out:
# 'CARRO'

# %%
b= "flor"
b.lower()
# Out:
# 'flor'
